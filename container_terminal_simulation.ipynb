# %%
# %run container_terminal_simulation.py
# Out:
# Enter the simulation time (in minutes):2000
# 8.32: Vessel_1 arrives.
# 8.32: Vessel_1 berths. (Waited 0.00 minutes)
# 8.32: Crane starts lifting container 1 from Vessel_1.
# 11.32: Truck starts transporting container 1 from Vessel_1.
# 17.32: Truck returns after dropping container 1 from Vessel_1.
# 17.32: Crane starts lifting container 2 from Vessel_1.
# 20.32: Truck starts transporting container 2 from Vessel_1.
# 26.32: Truck returns after dropping container 2 from Vessel_1.
# 26.32: Crane starts lifting container 3 from Vessel_1.
# 29.32: Truck starts transporting container 3 from Vessel_1.
# 35.32: Truck returns after dropping container 3 from Vessel_1.
# 35.32: Crane starts lifting container 4 from Vessel_1.
# 38.32: Truck starts transporting container 4 from Vessel_1.
# 44.32: Truck returns after dropping container 4 from Vessel_1.
# 44.32: Crane starts lifting container 5 from Vessel_1.
# 47.32: Truck starts transporting container 5 from Vessel_1.
# ...
